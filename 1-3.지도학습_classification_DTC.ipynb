# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
titanic_df = sns.load_dataset('titanic')

# %%
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
# 수치형 데이터 feature로만 구성된 DataFrame 만드기

numerical_cols = ["age", "sibsp", "parch", "fare"]
titanic_df[numerical_cols]
# Out:
#       age  sibsp  parch     fare
# 0    22.0      1      0   7.2500
# 1    38.0      1      0  71.2833
# 2    26.0      0      0   7.9250
# 3    35.0      1      0  53.1000
# 4    35.0      0      0   8.0500
# ..    ...    ...    ...      ...
# 886  27.0      0      0  13.0000
# 887  19.0      0      0  30.0000
# 888   NaN      1      2  23.4500
# 889  26.0      0      0  30.0000
# 890  32.0      0      0   7.7500
#
# [891 rows x 4 columns]

# %%
# alpha : 투명도
sns.histplot(data = titanic_df, x = 'age', hue = 'survived', bins = 30, alpha = 0.3);

# %%
sns.boxplot(data = titanic_df, x = 'sex', y = 'age', hue = 'pclass');

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
# 학습기 생성
model_sgdc = SGDClassifier()
#model_lr = LogisticRegression(solver='lbfgs', max_iter=1000)
model_lr = LogisticRegression()
model_rfc = RandomForestClassifier()

# %%
# 테스트 및 정확도
y_pred_sgdc = model_sgdc.predict(X_test)
y_pred_lr = model_lr.predict(X_test)
y_pred_rfc = model_rfc.predict(X_test)

print('1. sgdc 모델 예측 정확도: %.2f' % accuracy_score(y_test, y_pred_sgdc))
print('2. LR 모델 예측 정확도: %.2f' % accuracy_score(y_test, y_pred_lr))
print('3. rfc 모델 예측 정확도: %.2f' % accuracy_score(y_test, y_pred_rfc))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/junho/Documents/ml_scikit-learn/1-3.지도학습_classification_DTC.ipynb Cell 10' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/junho/Documents/ml_scikit-learn/1-3.%EC%A7%80%EB%8F%84%ED%95%99%EC%8A%B5_classification_DTC.ipynb#ch0000009?line=0'>1</a> # 테스트 및 정확도
# ----> <a href='vscode-notebook-cell:/Users/junho/Documents/ml_scikit-learn/1-3.%EC%A7%80%EB%8F%84%ED%95%99%EC%8A%B5_classification_DTC.ipynb#ch0000009?line=1'>2</a> y_pred_sgdc = model_sgdc.predict(X_test)
#       <a href='vscode-notebook-cell:/Users/junho/Documents/ml_scikit-learn/1-3.%EC%A7%80%EB%8F%84%ED%95%99%EC%8A%B5_classification_DTC.ipynb#ch0000009?line=2'>3</a> y_pred_lr = model_lr.predict(X_test)
#       <a href='vscode-notebook-cell:/Users/junho/Documents/ml_scikit-learn/1-3.%EC%A7%80%EB%8F%84%ED%95%99%EC%8A%B5_classification_DTC.ipynb#ch0000009?line=3'>4</a> y_pred_rfc = model_rfc.predict(X_test)
#
# NameError: name 'X_test' is not defined
